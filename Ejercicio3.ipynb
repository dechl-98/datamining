# %% [markdown]
# <a href="https://colab.research.google.com/github/dechl-98/datamining/blob/main/Ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/dechl-98/datamining/refs/heads/main/archivos/Ejercicio%203.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Weight  Cholesterol  Gender
# 0     102          111       1
# 1     115          135       1
# 2     115          136       1
# 3     140          167       0
# 4     130          158       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Weight       547 non-null    int64
#  1   Cholesterol  547 non-null    int64
#  2   Gender       547 non-null    int64
# dtypes: int64(3)
# memory usage: 12.9 KB

# %%
df.describe()
# Out:
#            Weight  Cholesterol      Gender
# count  547.000000   547.000000  547.000000
# mean   143.572212   170.433272    0.513711
# std     30.837275    39.147189    0.500269
# min     95.000000   102.000000    0.000000
# 25%    116.000000   136.000000    0.000000
# 50%    140.000000   169.000000    1.000000
# 75%    171.000000   208.000000    1.000000
# max    203.000000   235.000000    1.000000

# %%
df.isnull().sum()
# Out:
# Weight         0
# Cholesterol    0
# Gender         0
# dtype: int64

# %%
df_numeric = df.select_dtypes(include=['number'])

# %%
matriz = df_numeric.corr()
matriz
# Out:
#                Weight  Cholesterol    Gender
# Weight       1.000000     0.988593  0.006436
# Cholesterol  0.988593     1.000000 -0.010544
# Gender       0.006436    -0.010544  1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(matriz, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()
