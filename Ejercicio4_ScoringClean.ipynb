# %% [markdown]
# <a href="https://colab.research.google.com/github/dechl-98/datamining/blob/main/Ejercicio4_ScoringClean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://github.com/dechl-98/datamining/raw/refs/heads/main/archivos/Ejercicio%204_Scoring_clean.csv"
df = pd.read_csv(url, sep=';')
display(df.head())
# Out:
#     Age  Strength  Quickness  Injury  Vision  Endurance  Agility  \
# 0  18.5         5          1       1       0          5       33
# 1  13.3         1          2       1       3          5       18
# 2  13.4         2          1       0       2          5       40
# 3  16.3         3          1       0       2          5       32
# 4  15.7         1          1       0       2          3       43
#
#    Decision_Making
# 0               61
# 1               59
# 2               11
# 3               35
# 4               37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1767 entries, 0 to 1766
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              1767 non-null   float64
#  1   Strength         1767 non-null   int64
#  2   Quickness        1767 non-null   int64
#  3   Injury           1767 non-null   int64
#  4   Vision           1767 non-null   int64
#  5   Endurance        1767 non-null   int64
#  6   Agility          1767 non-null   int64
#  7   Decision_Making  1767 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 110.6 KB

# %%
df.describe()
# Out:
#                Age     Strength    Quickness       Injury       Vision  \
# count  1767.000000  1767.000000  1767.000000  1767.000000  1767.000000
# mean     15.982513     3.567063     1.987550     0.664969     1.599887
# std       1.729906     1.479915     1.551992     0.472135     1.188402
# min      13.000000     0.000000     0.000000     0.000000     0.000000
# 25%      14.500000     3.000000     1.000000     0.000000     0.000000
# 50%      16.000000     4.000000     1.000000     1.000000     2.000000
# 75%      17.400000     4.000000     2.000000     1.000000     3.000000
# max      19.000000     7.000000     6.000000     1.000000     3.000000
#
#          Endurance      Agility  Decision_Making
# count  1767.000000  1767.000000      1767.000000
# mean      3.736276    34.013016        29.946237
# std       1.366378    12.299599        21.116807
# min       0.000000    13.000000         3.000000
# 25%       3.000000    24.000000        11.000000
# ...

# %%
df.isnull().sum()
# Out:
# Age                0
# Strength           0
# Quickness          0
# Injury             0
# Vision             0
# Endurance          0
# Agility            0
# Decision_Making    0
# dtype: int64

# %%
df_numeric = df.select_dtypes(include=['number'])

# %%
matriz = df_numeric.corr()
matriz
# Out:
#                       Age  Strength  Quickness    Injury    Vision  Endurance  \
# Age              1.000000  0.026348  -0.003962  0.000657 -0.070943   0.010050
# Strength         0.026348  1.000000  -0.030700  0.015966 -0.189344  -0.191749
# Quickness       -0.003962 -0.030700   1.000000  0.019033  0.005587   0.056395
# Injury           0.000657  0.015966   0.019033  1.000000 -0.117943  -0.046630
# Vision          -0.070943 -0.189344   0.005587 -0.117943  1.000000   0.192335
# Endurance        0.010050 -0.191749   0.056395 -0.046630  0.192335   1.000000
# Agility          0.001136  0.313699  -0.112477  0.079052 -0.257998  -0.494283
# Decision_Making -0.017210 -0.039666   0.011556  0.074014  0.039194   0.094984
#
#                   Agility  Decision_Making
# Age              0.001136        -0.017210
# Strength         0.313699        -0.039666
# Quickness       -0.112477         0.011556
# Injury           0.079052         0.074014
# Vision          -0.257998         0.039194
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(matriz, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()
